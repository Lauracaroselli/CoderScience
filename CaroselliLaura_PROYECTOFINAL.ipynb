# %% [markdown]
# <a href="https://colab.research.google.com/github/Lauracaroselli/CoderScience/blob/main/CaroselliLaura_PROYECTOFINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Conjunto de datos del Informe Mundial sobre la Felicidad 2023**

# %% [markdown]
# ##Reseña del Dataset

# %% [markdown]
#   El dataset elegido corresponde a los datos obtenidos de la Encuesta Mundial Gallup, utilizados para el Informe Mundial de Felicidad 2023, y fue obtenido desde la página World Happiness Report.
#   El dataset corresponde a muestras tomadas desde el año 2005 al 2022.

# %% [markdown]
# ###Detalle de las columnas
#
# *   Country name: nombre del País
# *   Iso alpha: el código de país ISO alfa-3 para el país respectivo
# *   Year: año
# *   Happiness score: se basa en respuestas a la pregunta principal de evaluación de la vida. La Escalera Cantril pide a los encuestados que piensen en una escalera, en la que la mejor vida posible para ellos es un 10 y la peor vida posible es un 0. Luego se les pide que califiquen sus propias vidas actuales en esa escala de 0 a 10
# *   Log GDP per capita: El logaritmo del producto interno bruto (PIB) per cápita del país, una medida de prosperidad económica
# *   Social support: una medida del apoyo social percibido y las conexiones sociales disponibles para las personas en el país.
# *   Healthy life expectancy at birth: esperanza de vida saludable, número promedio de años que se espera que una persona viva con buena salud en el país.
# *   Freedom to make life choices: el grado en que los individuos perciben que tienen la libertad de tomar decisiones y elecciones en la vida.
# *   Generosity: el nivel de generosidad o comportamientos altruistas reportados por personas en el país.
# *   Perceptions of corruption: corrupción
# *   Positive affect: El afecto positivo se define como el promedio de tres medidas de afecto positivo en
# GWP: reír, disfrutar y hacer cosas interesantes en la Encuesta Mundial Gallup
# ondas 3-7. Estas medidas son las respuestas a las siguientes tres preguntas,
# respectivamente: “¿Sonreiste o reíste mucho ayer?” y “¿Experimentaste
# los siguientes sentimientos durante GRAN PARTE DEL DÍA de ayer? Qué tal si
# ¿Disfruto?”, “¿Aprendiste o hiciste algo interesante ayer?”
# *   Negative affect: El afecto negativo se define como el promedio de tres medidas de afecto negativo en
# PCG. Son preocupación, tristeza y enojo, respectivamente, las respuestas a “¿Lo hiciste?”
# ¿Experimentaste los siguientes sentimientos durante GRAN PARTE DEL DÍA de ayer?
# ¿Qué tal la preocupación?”, “¿Experimentaste los siguientes sentimientos durante MUCHO
# DEL DÍA de ayer? ¿Qué tal la Tristeza?” y “¿Experimentaste la
# siguientes sentimientos durante GRAN PARTE DEL DÍA de ayer? ¿Qué tal la ira?

# %% [markdown]
# ##Abstract

# %% [markdown]
# ###Motivación
# La investigación se abordó por la gran cantidad de información que hay sobre el tema, por la prolijidad de los datos contenidos en el dataset, hay una organización detrás de éste estudio que se encarga de realizar encuentas y recopilar los datos.
# Se analizarán las variables que se relacionan con la felicidad, para conocer cuál de ellas es la que más influye en la felicidad, cómo evolucionó en los años el índice, y obtener un ranking de países más felices y menos felices.

# %% [markdown]
# ### Audiencia
#
# Se aborda el estudio del presente Dataset con la finalidad de entender qué factores están asociados con la felicidad.
# El siguiente análisis puede ser de gran utilidad para el público en general, que esté interesado en conocer el comportamiento de la felicidad frente a determinadas variables proporcionando ideas que lleven a las personas a mejorar el bienestar personal y su nivel de felicidad.
# También las conclusiones podrían ser de utilidad para sociólogos y para políticos que quisieran tomar políticas sociales o económicas para mejorar la salud emocional de la población.

# %% [markdown]
# ## Hipótesis
# Se busca responder los siguientes interrogantes:
# - Distribución de los niveles de felicidad.
# - Determinar la relación existente entre el puntaje de felicidad y las variables.
# - ¿Cuál es la variable más sensible al nivel de felicidad?
# - Proporción de habitantes más satisfechos y menos satisfechos.
# - ¿Cómo evolucionó en los años el nivel de felicidad de las personas? y si existe una tendencia a los largo del tiempo.
# - Establecer un ranking de países más felices y menos felices.

# %% [markdown]
# ##Análisis exploratorio de los datos

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/Lauracaroselli/CoderScience/main/felicidad.csv"
felicidad= pd.read_csv(url,sep=',')
felicidad.head(20)
# Out:
#    Country name Iso alpha  year  Happiness score  Log GDP per capita  \
# 0   Afghanistan       AFG  2008            3.724               7.350
# 1   Afghanistan       AFG  2009            4.402               7.509
# 2   Afghanistan       AFG  2010            4.758               7.614
# 3   Afghanistan       AFG  2011            3.832               7.581
# 4   Afghanistan       AFG  2012            3.783               7.661
# 5   Afghanistan       AFG  2013            3.572               7.680
# 6   Afghanistan       AFG  2014            3.131               7.671
# 7   Afghanistan       AFG  2015            3.983               7.654
# 8   Afghanistan       AFG  2016            4.220               7.650
# 9   Afghanistan       AFG  2017            2.662               7.648
# 10  Afghanistan       AFG  2018            2.694               7.631
# 11  Afghanistan       AFG  2019            2.375               7.640
# 12  Afghanistan       AFG  2021            2.436               7.324
# ...

# %%
# se busca conocer la cantidad de países únicos hay con el fín de ver la cantidad de variables únicasy ver si es posible realizar algún gráfico teniendo en cuenta su dimensión.
num_valores_unicos = felicidad['Country name'].nunique()

print("Número de países únicos:", num_valores_unicos)
# Out:
# Número de países únicos: 165

# %%
# el siguiente código nos permite ver los años que forman parte del estudio
num_valores_unicos_años = felicidad['year'].unique()

print("años en estudio:", num_valores_unicos_años)
# Out:
# años en estudio: [2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2021 2022
#  2007 2020 2006 2005]

# %%
# solicitamos los nombres de las columnas
felicidad.columns
# Out:
# Index(['Country name', 'Iso alpha', 'year', 'Happiness score',
#        'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect'],
#       dtype='object')

# %%
# solicitamos la información del dataset, aquí se puede identificar si hay datos Null y el tipo de dato de cada columna.
felicidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      2199 non-null   object
#  1   Iso alpha                         2199 non-null   object
#  2   year                              2199 non-null   int64
#  3   Happiness score                   2199 non-null   float64
#  4   Log GDP per capita                2179 non-null   float64
#  5   Social support                    2186 non-null   float64
#  6   Healthy life expectancy at birth  2145 non-null   float64
#  7   Freedom to make life choices      2166 non-null   float64
#  8   Generosity                        2126 non-null   float64
#  9   Perceptions of corruption         2083 non-null   float64
#  10  Positive affect                   2175 non-null   float64
# ...

# %%
felicidad.shape
#nos brindael tamaño de las filas por las columnas
# Out:
# (2199, 12)

# %%
print(felicidad.isna().sum())
#suma los datos nulos de cada columna
# Out:
# Country name                          0
# Iso alpha                             0
# year                                  0
# Happiness score                       0
# Log GDP per capita                   20
# Social support                       13
# Healthy life expectancy at birth     54
# Freedom to make life choices         33
# Generosity                           73
# Perceptions of corruption           116
# Positive affect                      24
# Negative affect                      16
# dtype: int64

# %% [markdown]
# A continuación se muestran las correlaciones entre las variables numéricas, a fín de analizar cuáles son las variables importantes para el desarrollo del modelo.

# %%
# crear matriz de correlacion con seaborn

sns.heatmap(felicidad[['Happiness score', 'Log GDP per capita', 'Social support', 'Healthy life expectancy at birth', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Positive affect', 'Negative affect']].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Limpieza de datos
# Se procede a eliminar las columnas de variables sin correlación para el estudio de la variable Happines Score.
# Luego se eliminarán las filas Null.

# %%
# Eliminar la columna perception of corrupcion, Negative affect y generosity

felicidad.drop(['Perceptions of corruption', 'Negative affect', 'Generosity'], axis=1, inplace=True)
felicidad.head()
# Out:
#   Country name Iso alpha  year  Happiness score  Log GDP per capita  \
# 0  Afghanistan       AFG  2008            3.724               7.350
# 1  Afghanistan       AFG  2009            4.402               7.509
# 2  Afghanistan       AFG  2010            4.758               7.614
# 3  Afghanistan       AFG  2011            3.832               7.581
# 4  Afghanistan       AFG  2012            3.783               7.661
#
#    Social support  Healthy life expectancy at birth  \
# 0           0.451                              50.5
# 1           0.552                              50.8
# 2           0.539                              51.1
# 3           0.521                              51.4
# 4           0.521                              51.7
#
#    Freedom to make life choices  Positive affect
# 0                         0.718            0.414
# 1                         0.679            0.481
# 2                         0.600            0.517
# ...

# %%
print(felicidad.isna().sum())
# Out:
# Country name                         0
# Iso alpha                            0
# year                                 0
# Happiness score                      0
# Log GDP per capita                  20
# Social support                      13
# Healthy life expectancy at birth    54
# Freedom to make life choices        33
# Positive affect                     24
# dtype: int64

# %%
felicidad.shape
# Out:
# (2199, 9)

# %%
felicidad.describe().round(3)
# Out:
#            year  Happiness score  Log GDP per capita  Social support  \
# count  2199.000         2199.000            2179.000        2186.000
# mean   2014.161            5.479               9.390           0.811
# std       4.719            1.126               1.153           0.121
# min    2005.000            1.281               5.527           0.228
# 25%    2010.000            4.647               8.500           0.747
# 50%    2014.000            5.432               9.499           0.836
# 75%    2018.000            6.310              10.374           0.905
# max    2022.000            8.019              11.664           0.987
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                          2145.000                      2166.000
# mean                             63.295                         0.748
# std                               6.901                         0.140
# ...

# %%
# Eliminar las filas null

felicidad = felicidad.dropna()

# %%
felicidad.shape
#vemos que luego de la limpieza de los datos, sólo se eliminaron 115 filas y 3 columnas consideradas irrelevantes en el estudio por su escasa correlación con la variable Happiness Score.
# Out:
# (1958, 12)

# %%
print(felicidad.isna().sum())
# se realiza para corroborar que no hayan quedado filas con datos null.
# Out:
# Country name                        0
# Iso alpha                           0
# year                                0
# Happiness score                     0
# Log GDP per capita                  0
# Social support                      0
# Healthy life expectancy at birth    0
# Freedom to make life choices        0
# Generosity                          0
# Perceptions of corruption           0
# Positive affect                     0
# Negative affect                     0
# dtype: int64

# %%
felicidad.describe().round(3)
#podemos comparar éste cuadro con el obtenido antes de realizar la limpieza,los datos en la media y la mediana permanecen muy parecidos, por lo que la limpieza ha sido efectiva.
# Out:
#            year  Happiness score  Log GDP per capita  Social support  \
# count  1958.000         1958.000            1958.000        1958.000
# mean   2014.308            5.459               9.344           0.808
# std       4.640            1.141               1.158           0.123
# min    2005.000            2.179               5.527           0.290
# 25%    2011.000            4.609               8.442           0.739
# 50%    2014.000            5.391               9.494           0.834
# 75%    2018.000            6.274              10.303           0.906
# max    2022.000            7.971              11.664           0.987
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                          1958.000                      1958.000
# mean                             63.156                         0.745
# std                               7.069                         0.141
# ...

# %% [markdown]
# Con el siguiente gráfico lo que se quiere averiguar es cómo están distribuidos los datos de la variable Happiness Score, respecto de su frecuencia, se utiliza el Histograma de Matplotlib, con el que se concluye:
#
# *   Que la mayoría de los datos se encuentran distribuidos en valores por encima del 4 y llegan hasta el 8,5.
# *   Que la felicidad se puntuó desde 2, aunque son pocas personas las que puntuan a la felicidad con nota por debajo del 4.
# *   El puntaje de felicidad se mantiene centrado entre el 4,5 y el 6,5

# %%
fig, ax = plt.subplots (figsize=(10,4))
bines_personalizados = [0,0.5,1, 1.5,2, 2.5,3, 3.5,4, 4.5,5, 5.5,6, 6.5,7, 7.5,8, 8.5,9, 9.5, 10]
ax.hist(x=felicidad["Happiness score"],bins=bines_personalizados)
ax.set_xticks(range(0, 10,1))
ax.set_title("Frecuencia de los valores del Índice de Felicidad")
ax.set_xlabel("Intervalos de Felicidad")
ax.set_ylabel("Valores del Indice de Felicidad")
plt.show()

# %% [markdown]
# A continuación se buscaba ver los rangos de los quartiles, con el gráfico del Boxplot de Matplotlib, para ver con mayor definición en qué intervalos se distribuían los datos, la conclusión:
#
#
# *  La mitad de la gente puntúa a la felicidad entre el 2 y el 5,5, y la otra mitad, puntúa a la felicidad entre el 5,5 y el 8
# *   Punto medio significativo: El hecho de que la división entre las puntuaciones esté en 5.5, justo en el medio del rango de 0 a 10, sugiere que este punto podría ser significativo en términos de percepción de felicidad. Podría representar un umbral donde las personas experimentan un cambio notable en su nivel de satisfacción o bienestar.
# *  Diversidad en la percepción de la felicidad: La distribución de las puntuaciones sugiere una diversidad significativa en la percepción de la felicidad dentro de la población. Mientras que algunos individuos se sienten relativamente menos felices, otros se sienten más felices, lo que refleja una variedad de experiencias y perspectivas.
# *  Discrepancia en la satisfacción personal: La diferencia en las puntuaciones podría indicar que hay una discrepancia notable en la satisfacción personal entre diferentes grupos de personas. Aquellos que puntúan más bajo podrían estar experimentando desafíos o dificultades que impactan su felicidad, mientras que aquellos que puntúan más alto podrían estar experimentando un mayor bienestar o satisfacción en sus vidas.

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(felicidad['Happiness score'])
ax.set_yticks(range(0, 10,1))
plt.title('Boxplot del Índice de Felicidad')
plt.xlabel('')
plt.ylabel('Índice de Felicidad')
plt.grid(True)
plt.show()

# %% [markdown]
# El propósito del siguiente gráfico fue visualizar lo visto anteriormente, individualizado por año.
# Se utilizó la misma figura Boxplot de la galería Seaborn, y se separararon los datos por años.
# Como conclusión a un análisis de los años pasados en pandemia, se puede decir que la puntuación más alta fue disminuyendo y hubo más amplitud entre el mínimo puntaje con la media. Pero en todos los casos la Mediana se ubica dentro del rango de 5 a 6, a excepción del año 2005 que demostró un intervalo de datos más corto, con los datos más comprimidos y con un mayor nivel de felicidad general.
# El nivel más alto de felicidad se mantiene casi estable, mientras que el nivel más bajo de felicidad fluctúa subiendo y bajando cada año confirmando la discrepancia en la satisfacción personal.

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(x="year", y="Happiness score", data=felicidad)
plt.title('Boxplot del Índice de Felicidad')
plt.xlabel('year')
plt.ylabel('Happiness score')
plt.show()

# %% [markdown]
# Se utilizó el Scatter de la biblioteca Matplotlib, concluyendo que existe una clara relación entre el nivel de felicidad y el ingreso per cápita.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(felicidad['Happiness score'], felicidad['Log GDP per capita'], alpha=0.5, color='blue')  # alpha controla la transparencia de los puntos
plt.title('Gráfico de Dispersión entre el ídice de felicidad y el ingreso per cápita')
plt.xlabel('Indice de felicidad')
plt.ylabel('Log Ingreso per cápita')
plt.grid(True)
plt.show()

# %% [markdown]
# El siguiente, es el mismo gráfico que el anterior, pero se le agregó como tercer variable, los años, para que se pueda visualizar con mayor detalle los datos.

# %%
fig, ax=plt.subplots()
mapeo_colores=ax.scatter(felicidad['Happiness score'], felicidad['Log GDP per capita'], c=felicidad['year'])
fig.colorbar(mapeo_colores)
ax.set_title('Gráfico de Dispersión entre el Índice de Felicidad y el Ingreso Per Cápita')
ax.set_xlabel('Indice de felicidad')
ax.set_ylabel('Log Ingreso per cápita')
plt.grid(True)
plt.show()

# %% [markdown]
# El siguiente análisis es igual al anterior, pero analiza la relación entre la felicidad y la variable de Soporte Social, donde se concluye que existe una correlación, pero no es tan lineal como se ve en la variable anterior.

# %%
fig, ax=plt.subplots()
mapeo_colores=ax.scatter(felicidad['Happiness score'], felicidad['Social support'], c=felicidad['year'])
fig.colorbar(mapeo_colores)
ax.set_title('Gráfico de Dispersión entre el Índice de Felicidad y el Apoyo Social')
ax.set_xlabel('Indice de Felicidad')
ax.set_ylabel('Apoyo Social')
plt.grid(True)
plt.show()

# %% [markdown]
# Para seguir estudiando la relación entre el índice de la felicidad y la variable de Apoyo Social, se realiza a continuación el agrupamiento de los datos por país, tomando la media de los valores de las variables en estudio y un gráfico de líneas en seaborn con dichos datos obtenidos:

# %%
promedio_felicidad_por_país = felicidad.groupby('Country name').agg({'Happiness score': 'mean', 'Social support': 'mean'})

print(promedio_felicidad_por_país)
# Out:
#               Happiness score  Social support
# Country name
# Afghanistan          3.505538        0.504231
# Albania              5.047933        0.715800
# Algeria              5.230571        0.823857
# Angola               4.420250        0.738250
# Argentina            6.283588        0.902412
# ...                       ...             ...
# Venezuela            6.123143        0.917643
# Vietnam              5.445615        0.825077
# Yemen                3.912250        0.739833
# Zambia               4.453733        0.729800
# Zimbabwe             3.805294        0.784824
#
# [158 rows x 2 columns]

# %%
# Crear el gráfico de líneas
sns.lineplot(x='Happiness score', y='Social support', data=promedio_felicidad_por_país)

plt.show()

# %% [markdown]
# El gráfico muestra una tendencia entre el nivel de felicidad y el Apoyo Social. Pero los datos están muy dispersos, se seguirá analizando.

# %%
fig, ax=plt.subplots()
mapeo_colores=ax.scatter(felicidad['Happiness score'], felicidad['Healthy life expectancy at birth'], c=felicidad['year'])
fig.colorbar(mapeo_colores)
ax.set_title('Gráfico de Dispersión entre el Índice de Felicidad y la Expectativa de vida')
ax.set_xlabel('Indice de Felicidad')
ax.set_ylabel('Expectativa de vida')
plt.grid(True)
plt.show()

# %%
fig, ax=plt.subplots()
mapeo_colores=ax.scatter(felicidad['Happiness score'], felicidad['Freedom to make life choices'], c=felicidad['year'])
fig.colorbar(mapeo_colores)
ax.set_title('Gráfico de Dispersión entre el Índice de Felicidad y la Libertad para tomar decisiones')
ax.set_xlabel('Indice de Felicidad')
ax.set_ylabel('Libertad de decisiones')
plt.grid(True)
plt.show()

# %%
fig, ax=plt.subplots()
mapeo_colores=ax.scatter(felicidad['Happiness score'], felicidad['Positive affect'], c=felicidad['year'])
fig.colorbar(mapeo_colores)
ax.set_title('Gráfico de Dispersión entre el Índice de Felicidad y Aspectos Positivos')
ax.set_xlabel('Indice de Felicidad')
ax.set_ylabel('Aspectos Positivos')
plt.grid(True)
plt.show()

# %% [markdown]
# Las últimas dos variables, muestran una correlacion, pero no tan fuerte, con los datos más dispersos.

# %% [markdown]
# La conclusión es que las variables más fuertes para predecir el nivel de felicidad son: el Ingreso per cápita, el Apoyo Social y las Expectativas de vida.

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
#CREAR un modelo de test y prueba

from sklearn.model_selection import train_test_split

# Dividir los datos en conjuntos de entrenamiento y prueba
X = felicidad[['Log GDP per capita']]  # Variable independiente
y = felicidad[['Happiness score']]  # Variable dependiente

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

print('Datos de entrenamiento:', X_train.shape, y_train.shape)
print('Datos de prueba:', X_test.shape, y_test.shape)
# Out:
# Datos de entrenamiento: (1458, 1) (1458, 1)
# Datos de prueba: (626, 1) (626, 1)

# %%
# crear el modelo
modelo_ingreso = LinearRegression()
# Ajustar el modelo con X_train y y_train
modelo_ingreso.fit(X_train,y_train)
# PRedecir con X_test
y_pred = modelo_ingreso.predict(X_test)
y_pred_train = modelo_ingreso.predict(X_train)

# %%
# Obtener la pendiente
slope = modelo_ingreso.coef_

# Obtener los coeficientes de intercepción
intercept = modelo_ingreso.intercept_

print("este es el valor de la pendiente:", slope.round(1))
print("este es el valor del intercepto:", intercept.round(1))
# Out:
# este es el valor de la pendiente: [[0.8]]
# este es el valor del intercepto: [-1.7]

# %%
#Visualización de los datos de entrenamiento

viz_train = plt
viz_train.scatter(X_train, y_train, color = 'g')
viz_train.plot(X_train, modelo_ingreso.predict(X_train), color = 'black')
viz_train.title('Ingreso per capita vs Happiness Score')
viz_train.xlabel('Log GDP per capita')
viz_train.ylabel('Happiness Score')
viz_train.show()

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.529427487683918

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_train,y_pred_train))
# Out:
# MAE 0.5696110264364969

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 0.4303790466881657

# %%
from sklearn.metrics import mean_squared_error
print("MSE",mean_squared_error(y_train,y_pred_train))
# Out:
# MSE 0.5076169708468323

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 0.6560328091552782

# %%
print("RMSE",np.sqrt(mean_squared_error(y_train,y_pred_train)))
# Out:
# RMSE 0.7124724351487799

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.6393180818249713

# %%
r2 = r2_score(y_train,y_pred_train)
print(r2)
# Out:
# 0.6173691525486631

# %%
#CREAR un modelo de test y prueba

from sklearn.model_selection import train_test_split

# Dividir los datos en conjuntos de entrenamiento y prueba
X = felicidad[['Social support']]  # Variable independiente
y = felicidad[['Happiness score']]  # Variable dependiente

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

print('Datos de entrenamiento:', X_train.shape, y_train.shape)
print('Datos de prueba:', X_test.shape, y_test.shape)
# Out:
# Datos de entrenamiento: (1458, 1) (1458, 1)
# Datos de prueba: (626, 1) (626, 1)

# %%
# crear el modelo
modelo_social_support = LinearRegression()
# Ajustar el modelo con X_train y y_train
modelo_social_support.fit(X_train,y_train)
# PRedecir con X_test
y_pred = modelo_social_support.predict(X_test)
y_pred_train = modelo_social_support.predict(X_train)

# %%
# Obtener la pendiente
slope = modelo_social_support.coef_

# Obtener los coeficientes de intercepción
intercept = modelo_social_support.intercept_

print("este es el valor de la pendiente:", slope.round(1))
print("este es el valor del intercepto:", intercept.round(1))
# Out:
# este es el valor de la pendiente: [[6.7]]
# este es el valor del intercepto: [0.1]

# %%
#Visualización de los datos de entrenamiento

viz_train = plt
viz_train.scatter(X_train, y_train, color = 'g')
viz_train.plot(X_train, modelo_social_support.predict(X_train), color = 'black')
viz_train.title('Social Support vs Happiness Score')
viz_train.xlabel('Social Support')
viz_train.ylabel('Happiness Score')
viz_train.show()

# %%
from sklearn.metrics import mean_absolute_error
print("MAE",mean_absolute_error(y_test,y_pred))
print("MAE",mean_absolute_error(y_train,y_pred_train))
# Out:
# MAE 0.6142073524690477
# MAE 0.6521097802318921

# %%
print("MSE",mean_squared_error(y_test,y_pred))
print("MSE",mean_squared_error(y_train,y_pred_train))
# Out:
# MSE 0.5853250706142237
# MSE 0.6317283969230637

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
print("RMSE",np.sqrt(mean_squared_error(y_train,y_pred_train)))
# Out:
# RMSE 0.7650654028344398
# RMSE 0.7948134352935057

# %%
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.5094645734971432

# %%
r2 = r2_score(y_train,y_pred_train)
print(r2)
# Out:
# 0.52381660630751

# %%
# Dividir los datos en conjuntos de entrenamiento y prueba
X = felicidad[['Healthy life expectancy at birth']]  # Variable independiente
y = felicidad[['Happiness score']]  # Variable dependiente

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

print('Datos de entrenamiento:', X_train.shape, y_train.shape)
print('Datos de prueba:', X_test.shape, y_test.shape)
# Out:
# Datos de entrenamiento: (1458, 1) (1458, 1)
# Datos de prueba: (626, 1) (626, 1)

# %%
# crear el modelo
modelo_esperanza_vida = LinearRegression()
# Ajustar el modelo con X_train y y_train
modelo_esperanza_vida.fit(X_train,y_train)
# PRedecir con X_test
y_pred = modelo_esperanza_vida.predict(X_test)
y_pred_train = modelo_esperanza_vida.predict(X_train)

# %%
# Obtener la pendiente
slope = modelo_esperanza_vida.coef_

# Obtener los coeficientes de intercepción
intercept = modelo_esperanza_vida.intercept_

print("este es el valor de la pendiente:", slope.round(1))
print("este es el valor del intercepto:", intercept.round(1))
# Out:
# este es el valor de la pendiente: [[0.1]]
# este es el valor del intercepto: [-1.9]

# %%
#Visualización de los datos de entrenamiento

viz_train = plt
viz_train.scatter(X_train, y_train, color = 'g')
viz_train.plot(X_train, modelo_esperanza_vida.predict(X_train), color = 'black')
viz_train.title('Esperanza de vida vs Happiness Score')
viz_train.xlabel('Esperanza de vida')
viz_train.ylabel('Happiness Score')
viz_train.show()

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MAE",mean_absolute_error(y_train,y_pred_train))
# Out:
# MAE 0.6067098102182558
# MAE 0.6494217729609815

# %%
print("MSE",mean_squared_error(y_test,y_pred))
print("MSE",mean_squared_error(y_train,y_pred_train))
# Out:
# MSE 0.5673473438860414
# MSE 0.6475309292751387

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
print("RMSE",np.sqrt(mean_squared_error(y_train,y_pred_train)))
# Out:
# RMSE 0.7532246304297552
# RMSE 0.8046930652585113

# %%
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.5245309225925383

# %%
r2 = r2_score(y_train,y_pred_train)
print(r2)
# Out:
# 0.511904994417024
